# %% [markdown]
# # Solución Unificada: Ejercicios Extra CSV (2.6, 2.7, 2.8)
#
# **Institución:** Universidad San Sebastián · Sede Patagonia
# **Asignatura:** Taller de Programación II
# **Contenido:** Resoluciones docentes de los ejercicios de práctica en CSV.
#
# ---

# %% [markdown]
# ## Ejercicio 2.6: Gestor de Productos (`productos_extra.csv`)

# %%
from ejercicios_extra_csv import registrar_producto, ARCHIVO_PRODUCTOS

registrar_producto("Monitor IPS 27", 189000, 10)
print(f"¿Existe archivo de productos? {ARCHIVO_PRODUCTOS.exists()}")
# Out:
# ✅ Archivo 'productos_extra.csv' creado con sus encabezados.
# ✅ Producto registrado: Monitor IPS 27 | $189000 | Stock: 10
# ¿Existe archivo de productos? True

# %% [markdown]
# ## Ejercicio 2.7: Gestor de Sensores e Inspección con Rangos Físicos

# %%
from ejercicios_extra_csv import registrar_medicion_sensor

registrar_medicion_sensor("Sensor-Termico-01", "45.0", "1013.2", "55.0")
registrar_medicion_sensor("Sensor-Invalido", "300.0", "100.0", "50.0")
# Out:
# ✅ Archivo 'mediciones_sensores.csv' creado con sus encabezados.
# ✅ Medición registrada [Sensor-Termico-01]: Temp=45.0°C, Presion=1013.2hPa, Hum=55.0%
# ❌ Error en Sensor: Temperatura fuera de rango físico (-50 a 150 °C): 300.0

# %% [markdown]
# ## Ejercicio 2.8: Gestor de Mantenciones con Estampa de Fecha (`datetime`)

# %%
from ejercicios_extra_csv import agregar_mantencion_auto_fecha

agregar_mantencion_auto_fecha("Generador Auxiliar", "Moisés Vera", "Prueba de carga y filtro de aire")
# Out:
# ✅ Archivo 'bitacora_mantenciones.csv' creado con sus encabezados.
# ✅ Mantención registrada [2026-08-30]: Equipo 'Generador Auxiliar' por Técnico 'Moisés Vera'
