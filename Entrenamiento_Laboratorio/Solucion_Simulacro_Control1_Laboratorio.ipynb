# %% [markdown]
# # 📋 Pauta Oficial de Solución — Simulacro Control 1 de Laboratorio
#
# **Asignatura:** Taller de Programación II
# **Evaluación:** Control 1 (Laboratorio · 10%)
# **Dominio:** Sistema de Préstamos de Equipos de Laboratorio USS
#
# ---
#
# ## 🎯 Pauta y Criterios de Evaluación
#
# 1. **Creación Defensiva de Rutas (`pathlib.Path`):** 1.0 punto.
# 2. **Serialización CSV (`csv.writer`, `newline=""`):** 1.5 puntos.
# 3. **Manejo de Excepciones (`try-except ValueError`):** 1.5 puntos.
# 4. **Reescritura Atómica en Modo `'w'` (Devoluciones):** 1.5 puntos.
# 5. **Exportación Estadísticas a JSON (`json.dump`):** 1.5 puntos.

# %%
from simulacro_control1_laboratorio import (
    asegurar_archivo_prestamos,
    leer_prestamos,
    exportar_resumen_json,
    ARCHIVO_CSV_PRESTAMOS,
)

asegurar_archivo_prestamos()
prestamos = leer_prestamos()
print(f"Estado inicial de prestamos en disk: {len(prestamos)} registros.")
exportar_resumen_json()
# Out:
# Estado inicial de prestamos en disk: 0 registros.
# 📊 Resumen JSON exportado exitosamente en 'resumen_prestamos.json'.
